# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pickle, pickletools

# %%
df = pd.read_csv('train_csv.csv')
df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})
df['Married'] = df['Married'].map({'No' : 0, 'Yes' : 1})
df['Loan_Status'] = df['Loan_Status'].map({'N' : 0, 'Y' : 1})

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    float64
#  2   Married            480 non-null    float64
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    int64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 52.5+ KB

# %%
x = df[['Gender', 'Married', 'LoanAmount', 'ApplicantIncome', 'Credit_History']]
y = df['Loan_Status']

# %%
x.iloc[0,:]
# Out:
# Gender                0.0
# Married               1.0
# LoanAmount          128.0
# ApplicantIncome    4583.0
# Credit_History        1.0
# Name: 1, dtype: float64

# %%
model = LogisticRegression(max_iter=200).fit(x, y)
model
# Out:
# LogisticRegression(max_iter=200)

# %%
accuracy = accuracy_score(y, model.predict(x))
accuracy
# Out:
# 0.8083333333333333

# %%
with open('classifier.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
pickletools.dis(open('classifier.pkl', 'rb'))
# Out:
#     0: \x80 PROTO      4
#     2: \x95 FRAME      898
#    11: \x8c SHORT_BINUNICODE 'sklearn.linear_model._logistic'
#    43: \x94 MEMOIZE    (as 0)
#    44: \x8c SHORT_BINUNICODE 'LogisticRegression'
#    64: \x94 MEMOIZE    (as 1)
#    65: \x93 STACK_GLOBAL
#    66: \x94 MEMOIZE    (as 2)
#    67: )    EMPTY_TUPLE
#    68: \x81 NEWOBJ
#    69: \x94 MEMOIZE    (as 3)
#    70: }    EMPTY_DICT
#    71: \x94 MEMOIZE    (as 4)
#    72: (    MARK
#    73: \x8c     SHORT_BINUNICODE 'penalty'
#    82: \x94     MEMOIZE    (as 5)
#    83: \x8c     SHORT_BINUNICODE 'l2'
#    87: \x94     MEMOIZE    (as 6)
#    88: \x8c     SHORT_BINUNICODE 'dual'
#    94: \x94     MEMOIZE    (as 7)
#    95: \x89     NEWFALSE
#    96: \x8c     SHORT_BINUNICODE 'tol'
#   101: \x94     MEMOIZE    (as 8)
#   102: G        BINFLOAT   0.0001
#   111: \x8c     SHORT_BINUNICODE 'C'
#   114: \x94     MEMOIZE    (as 9)
#   115: G        BINFLOAT   1.0
#   124: \x8c     SHORT_BINUNICODE 'fit_intercept'
#   139: \x94     MEMOIZE    (as 10)
#   140: \x88     NEWTRUE
#   141: \x8c     SHORT_BINUNICODE 'intercept_scaling'
#   160: \x94     MEMOIZE    (as 11)
#   161: K        BININT1    1
#   163: \x8c     SHORT_BINUNICODE 'class_weight'
#   177: \x94     MEMOIZE    (as 12)
#   178: N        NONE
#   179: \x8c     SHORT_BINUNICODE 'random_state'
#   193: \x94     MEMOIZE    (as 13)
#   194: N        NONE
#   195: \x8c     SHORT_BINUNICODE 'solver'
#   203: \x94     MEMOIZE    (as 14)
#   204: \x8c     SHORT_BINUNICODE 'lbfgs'
#   211: \x94     MEMOIZE    (as 15)
#   212: \x8c     SHORT_BINUNICODE 'max_iter'
#   222: \x94     MEMOIZE    (as 16)
#   223: K        BININT1    200
#   225: \x8c     SHORT_BINUNICODE 'multi_class'
#   238: \x94     MEMOIZE    (as 17)
#   239: \x8c     SHORT_BINUNICODE 'deprecated'
#   251: \x94     MEMOIZE    (as 18)
#   252: \x8c     SHORT_BINUNICODE 'verbose'
#   261: \x94     MEMOIZE    (as 19)
#   262: K        BININT1    0
#   264: \x8c     SHORT_BINUNICODE 'warm_start'
#   276: \x94     MEMOIZE    (as 20)
#   277: \x89     NEWFALSE
#   278: \x8c     SHORT_BINUNICODE 'n_jobs'
#   286: \x94     MEMOIZE    (as 21)
#   287: N        NONE
#   288: \x8c     SHORT_BINUNICODE 'l1_ratio'
#   298: \x94     MEMOIZE    (as 22)
#   299: N        NONE
#   300: \x8c     SHORT_BINUNICODE 'feature_names_in_'
#   319: \x94     MEMOIZE    (as 23)
#   320: \x8c     SHORT_BINUNICODE 'numpy._core.multiarray'
#   344: \x94     MEMOIZE    (as 24)
#   345: \x8c     SHORT_BINUNICODE '_reconstruct'
#   359: \x94     MEMOIZE    (as 25)
#   360: \x93     STACK_GLOBAL
#   361: \x94     MEMOIZE    (as 26)
#   362: \x8c     SHORT_BINUNICODE 'numpy'
#   369: \x94     MEMOIZE    (as 27)
#   370: \x8c     SHORT_BINUNICODE 'ndarray'
#   379: \x94     MEMOIZE    (as 28)
#   380: \x93     STACK_GLOBAL
#   381: \x94     MEMOIZE    (as 29)
#   382: K        BININT1    0
#   384: \x85     TUPLE1
#   385: \x94     MEMOIZE    (as 30)
#   386: C        SHORT_BINBYTES b'b'
#   389: \x94     MEMOIZE    (as 31)
#   390: \x87     TUPLE3
#   391: \x94     MEMOIZE    (as 32)
#   392: R        REDUCE
#   393: \x94     MEMOIZE    (as 33)
#   394: (        MARK
#   395: K            BININT1    1
#   397: K            BININT1    5
#   399: \x85         TUPLE1
#   400: \x94         MEMOIZE    (as 34)
#   401: h            BINGET     27
#   403: \x8c         SHORT_BINUNICODE 'dtype'
#   410: \x94         MEMOIZE    (as 35)
#   411: \x93         STACK_GLOBAL
#   412: \x94         MEMOIZE    (as 36)
#   413: \x8c         SHORT_BINUNICODE 'O8'
#   417: \x94         MEMOIZE    (as 37)
#   418: \x89         NEWFALSE
#   419: \x88         NEWTRUE
#   420: \x87         TUPLE3
#   421: \x94         MEMOIZE    (as 38)
#   422: R            REDUCE
#   423: \x94         MEMOIZE    (as 39)
#   424: (            MARK
#   425: K                BININT1    3
#   427: \x8c             SHORT_BINUNICODE '|'
#   430: \x94             MEMOIZE    (as 40)
#   431: N                NONE
#   432: N                NONE
#   433: N                NONE
#   434: J                BININT     -1
#   439: J                BININT     -1
#   444: K                BININT1    63
#   446: t                TUPLE      (MARK at 424)
#   447: \x94         MEMOIZE    (as 41)
#   448: b            BUILD
#   449: \x89         NEWFALSE
#   450: ]            EMPTY_LIST
#   451: \x94         MEMOIZE    (as 42)
#   452: (            MARK
#   453: \x8c             SHORT_BINUNICODE 'Gender'
#   461: \x94             MEMOIZE    (as 43)
#   462: \x8c             SHORT_BINUNICODE 'Married'
#   471: \x94             MEMOIZE    (as 44)
#   472: \x8c             SHORT_BINUNICODE 'LoanAmount'
#   484: \x94             MEMOIZE    (as 45)
#   485: \x8c             SHORT_BINUNICODE 'ApplicantIncome'
#   502: \x94             MEMOIZE    (as 46)
#   503: \x8c             SHORT_BINUNICODE 'Credit_History'
#   519: \x94             MEMOIZE    (as 47)
#   520: e                APPENDS    (MARK at 452)
#   521: t            TUPLE      (MARK at 394)
#   522: \x94     MEMOIZE    (as 48)
#   523: b        BUILD
#   524: \x8c     SHORT_BINUNICODE 'n_features_in_'
#   540: \x94     MEMOIZE    (as 49)
#   541: K        BININT1    5
#   543: \x8c     SHORT_BINUNICODE 'classes_'
#   553: \x94     MEMOIZE    (as 50)
#   554: h        BINGET     26
#   556: h        BINGET     29
#   558: K        BININT1    0
#   560: \x85     TUPLE1
#   561: \x94     MEMOIZE    (as 51)
#   562: h        BINGET     31
#   564: \x87     TUPLE3
#   565: \x94     MEMOIZE    (as 52)
#   566: R        REDUCE
#   567: \x94     MEMOIZE    (as 53)
#   568: (        MARK
#   569: K            BININT1    1
#   571: K            BININT1    2
#   573: \x85         TUPLE1
#   574: \x94         MEMOIZE    (as 54)
#   575: h            BINGET     36
#   577: \x8c         SHORT_BINUNICODE 'i8'
#   581: \x94         MEMOIZE    (as 55)
#   582: \x89         NEWFALSE
#   583: \x88         NEWTRUE
#   584: \x87         TUPLE3
#   585: \x94         MEMOIZE    (as 56)
#   586: R            REDUCE
#   587: \x94         MEMOIZE    (as 57)
#   588: (            MARK
#   589: K                BININT1    3
#   591: \x8c             SHORT_BINUNICODE '<'
#   594: \x94             MEMOIZE    (as 58)
#   595: N                NONE
#   596: N                NONE
#   597: N                NONE
#   598: J                BININT     -1
#   603: J                BININT     -1
#   608: K                BININT1    0
#   610: t                TUPLE      (MARK at 588)
#   611: \x94         MEMOIZE    (as 59)
#   612: b            BUILD
#   613: \x89         NEWFALSE
#   614: C            SHORT_BINBYTES b'\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00'
#   632: \x94         MEMOIZE    (as 60)
#   633: t            TUPLE      (MARK at 568)
#   634: \x94     MEMOIZE    (as 61)
#   635: b        BUILD
#   636: \x8c     SHORT_BINUNICODE 'n_iter_'
#   645: \x94     MEMOIZE    (as 62)
#   646: h        BINGET     26
#   648: h        BINGET     29
#   650: K        BININT1    0
#   652: \x85     TUPLE1
#   653: \x94     MEMOIZE    (as 63)
#   654: h        BINGET     31
#   656: \x87     TUPLE3
#   657: \x94     MEMOIZE    (as 64)
#   658: R        REDUCE
#   659: \x94     MEMOIZE    (as 65)
#   660: (        MARK
#   661: K            BININT1    1
#   663: K            BININT1    1
#   665: \x85         TUPLE1
#   666: \x94         MEMOIZE    (as 66)
#   667: h            BINGET     36
#   669: \x8c         SHORT_BINUNICODE 'i4'
#   673: \x94         MEMOIZE    (as 67)
#   674: \x89         NEWFALSE
#   675: \x88         NEWTRUE
#   676: \x87         TUPLE3
#   677: \x94         MEMOIZE    (as 68)
#   678: R            REDUCE
#   679: \x94         MEMOIZE    (as 69)
#   680: (            MARK
#   681: K                BININT1    3
#   683: h                BINGET     58
#   685: N                NONE
#   686: N                NONE
#   687: N                NONE
#   688: J                BININT     -1
#   693: J                BININT     -1
#   698: K                BININT1    0
#   700: t                TUPLE      (MARK at 680)
#   701: \x94         MEMOIZE    (as 70)
#   702: b            BUILD
#   703: \x89         NEWFALSE
#   704: C            SHORT_BINBYTES b'~\x00\x00\x00'
#   710: \x94         MEMOIZE    (as 71)
#   711: t            TUPLE      (MARK at 660)
#   712: \x94     MEMOIZE    (as 72)
#   713: b        BUILD
#   714: \x8c     SHORT_BINUNICODE 'coef_'
#   721: \x94     MEMOIZE    (as 73)
#   722: h        BINGET     26
#   724: h        BINGET     29
#   726: K        BININT1    0
#   728: \x85     TUPLE1
#   729: \x94     MEMOIZE    (as 74)
#   730: h        BINGET     31
#   732: \x87     TUPLE3
#   733: \x94     MEMOIZE    (as 75)
#   734: R        REDUCE
#   735: \x94     MEMOIZE    (as 76)
#   736: (        MARK
#   737: K            BININT1    1
#   739: K            BININT1    1
#   741: K            BININT1    5
#   743: \x86         TUPLE2
#   744: \x94         MEMOIZE    (as 77)
#   745: h            BINGET     36
#   747: \x8c         SHORT_BINUNICODE 'f8'
#   751: \x94         MEMOIZE    (as 78)
#   752: \x89         NEWFALSE
#   753: \x88         NEWTRUE
#   754: \x87         TUPLE3
#   755: \x94         MEMOIZE    (as 79)
#   756: R            REDUCE
#   757: \x94         MEMOIZE    (as 80)
#   758: (            MARK
#   759: K                BININT1    3
#   761: h                BINGET     58
#   763: N                NONE
#   764: N                NONE
#   765: N                NONE
#   766: J                BININT     -1
#   771: J                BININT     -1
#   776: K                BININT1    0
#   778: t                TUPLE      (MARK at 758)
#   779: \x94         MEMOIZE    (as 81)
#   780: b            BUILD
#   781: \x89         NEWFALSE
#   782: C            SHORT_BINBYTES b'\x03\xbc8\xc5\x94\xc5\xc5\xbfLc\x18\x00\xdd\x86\xe2?Ch\xb4\x0f\xc7\x04g\xbf\xd1\xf3z\x0c\xee:\xe6>,\xef\x8a\xb3\xee\xcf\x08@'
#   824: \x94         MEMOIZE    (as 82)
#   825: t            TUPLE      (MARK at 736)
#   826: \x94     MEMOIZE    (as 83)
#   827: b        BUILD
#   828: \x8c     SHORT_BINUNICODE 'intercept_'
#   840: \x94     MEMOIZE    (as 84)
#   841: h        BINGET     26
#   843: h        BINGET     29
#   845: K        BININT1    0
#   847: \x85     TUPLE1
#   848: \x94     MEMOIZE    (as 85)
#   849: h        BINGET     31
#   851: \x87     TUPLE3
#   852: \x94     MEMOIZE    (as 86)
#   853: R        REDUCE
#   854: \x94     MEMOIZE    (as 87)
#   855: (        MARK
#   856: K            BININT1    1
#   858: K            BININT1    1
#   860: \x85         TUPLE1
#   861: \x94         MEMOIZE    (as 88)
#   862: h            BINGET     80
#   864: \x89         NEWFALSE
#   865: C            SHORT_BINBYTES b'\xc32\xe8\x94\x0ek\xfc\xbf'
#   875: \x94         MEMOIZE    (as 89)
#   876: t            TUPLE      (MARK at 855)
#   877: \x94     MEMOIZE    (as 90)
#   878: b        BUILD
#   879: \x8c     SHORT_BINUNICODE '_sklearn_version'
#   897: \x94     MEMOIZE    (as 91)
#   898: \x8c     SHORT_BINUNICODE '1.6.1'
#   905: \x94     MEMOIZE    (as 92)
#   906: u        SETITEMS   (MARK at 72)
#   907: b    BUILD
#   908: .    STOP
# highest protocol among opcodes = 4
